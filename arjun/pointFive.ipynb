# %% [markdown]
# Installing packages

# %%
# !pip install langchain
# !pip install numpy
# !pip install opencv-python
# !pip install pillow
# !pip install torch 
# !pip install matplotlib
# !pip install openai
# Out:
# Requirement already satisfied: langchain in ./.conda/lib/python3.11/site-packages (0.1.13)
# Requirement already satisfied: PyYAML>=5.3 in ./.conda/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.conda/lib/python3.11/site-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.conda/lib/python3.11/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.conda/lib/python3.11/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.conda/lib/python3.11/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in ./.conda/lib/python3.11/site-packages (from langchain) (0.0.29)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in ./.conda/lib/python3.11/site-packages (from langchain) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in ./.conda/lib/python3.11/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./.conda/lib/python3.11/site-packages (from langchain) (0.1.31)
# Requirement already satisfied: numpy<2,>=1 in ./.conda/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in ./.conda/lib/python3.11/site-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in ./.conda/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./.conda/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.conda/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.conda/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in ./.conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain) (4.3.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in ./.conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.conda/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.conda/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./.conda/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.conda/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in ./.conda/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/lib/python3.11/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.conda/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: numpy in ./.conda/lib/python3.11/site-packages (1.26.4)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in ./.conda/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Requirement already satisfied: pillow in ./.conda/lib/python3.11/site-packages (10.2.0)
# Requirement already satisfied: torch in ./.conda/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: filelock in ./.conda/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.conda/lib/python3.11/site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in ./.conda/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in ./.conda/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in ./.conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.conda/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./.conda/lib/python3.11/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in ./.conda/lib/python3.11/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: matplotlib in ./.conda/lib/python3.11/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/lib/python3.11/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./.conda/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./.conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.conda/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting openai
#   Downloading openai-1.14.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.conda/lib/python3.11/site-packages (from openai) (4.3.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.conda/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.conda/lib/python3.11/site-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in ./.conda/lib/python3.11/site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.conda/lib/python3.11/site-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in ./.conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Downloading openai-1.14.2-py3-none-any.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 7.2 MB/s eta 0:00:00:00:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: tqdm, distro, openai
# Successfully installed distro-1.9.0 openai-1.14.2 tqdm-4.66.2

# %%
# !pip install replicate
# !pip install torchvision
# Out:
# Requirement already satisfied: replicate in ./.conda/lib/python3.11/site-packages (0.25.0)
# Requirement already satisfied: httpx<1,>=0.21.0 in ./.conda/lib/python3.11/site-packages (from replicate) (0.27.0)
# Requirement already satisfied: packaging in ./.conda/lib/python3.11/site-packages (from replicate) (23.2)
# Requirement already satisfied: pydantic>1.10.7 in ./.conda/lib/python3.11/site-packages (from replicate) (2.6.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.conda/lib/python3.11/site-packages (from replicate) (4.10.0)
# Requirement already satisfied: anyio in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (4.3.0)
# Requirement already satisfied: certifi in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (1.0.4)
# Requirement already satisfied: idna in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (3.6)
# Requirement already satisfied: sniffio in ./.conda/lib/python3.11/site-packages (from httpx<1,>=0.21.0->replicate) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.conda/lib/python3.11/site-packages (from pydantic>1.10.7->replicate) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./.conda/lib/python3.11/site-packages (from pydantic>1.10.7->replicate) (2.16.3)
# Collecting torchvision
#   Downloading torchvision-0.17.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in ./.conda/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.2.1 in ./.conda/lib/python3.11/site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.conda/lib/python3.11/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (4.10.0)
# Requirement already satisfied: sympy in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (1.12)
# Requirement already satisfied: networkx in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (3.1.3)
# Requirement already satisfied: fsspec in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in ./.conda/lib/python3.11/site-packages (from torch==2.2.1->torchvision) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->torchvision) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.11/site-packages (from jinja2->torch==2.2.1->torchvision) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in ./.conda/lib/python3.11/site-packages (from sympy->torch==2.2.1->torchvision) (1.3.0)
# Downloading torchvision-0.17.1-cp311-cp311-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 62.1 MB/s eta 0:00:00:00:010:01
# Installing collected packages: torchvision
# Successfully installed torchvision-0.17.1

# %% [markdown]
# Imports

# %%
import os
import cv2
import numpy as np
from PIL import Image
import torch
from torchvision import models, transforms
import matplotlib
import matplotlib.pyplot as plt
from openai import OpenAI
import replicate
from PIL import ImageFilter
